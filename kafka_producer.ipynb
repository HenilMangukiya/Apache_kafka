# %%
# !pip install kafka-python gspread oauth2client pandas yfinance
# Out:
# Requirement already satisfied: kafka-python in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (2.0.5)
# Requirement already satisfied: gspread in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (6.2.0)
# Requirement already satisfied: oauth2client in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (4.1.3)
# Requirement already satisfied: pandas in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (2.2.3)
# Requirement already satisfied: yfinance in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (0.2.54)
# Requirement already satisfied: google-auth>=1.12.0 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from gspread) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from gspread) (1.2.1)
# Requirement already satisfied: httplib2>=0.9.1 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from oauth2client) (0.22.0)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from oauth2client) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from oauth2client) (0.4.1)
# Requirement already satisfied: rsa>=3.1.4 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from oauth2client) (4.9)
# Requirement already satisfied: six>=1.6.1 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from oauth2client) (1.17.0)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: requests>=2.31 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (4.13.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.12.0->gspread) (5.5.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from google-auth-oauthlib>=0.4.1->gspread) (2.0.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from httplib2>=0.9.1->oauth2client) (3.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (2025.1.31)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (0.2.54)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: requests>=2.31 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2025.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (4.13.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (2025.1.31)
# Requirement already satisfied: six>=1.5 in c:\users\henil\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)

# %%
import gspread
from kafka import KafkaProducer
import yfinance as yf
import json
import time
from oauth2client.service_account import ServiceAccountCredentials

# 🔹 Google Sheets Authentication
scope = ["https://spreadsheets.google.com/feeds", "https://www.googleapis.com/auth/drive"]
creds = ServiceAccountCredentials.from_json_keyfile_name("stock-market-data-project-446c6101e293.json", scope)

# 🔹 Retry connecting to Google Sheets
for attempt in range(5):
    try:
        client = gspread.authorize(creds)
        spreadsheet = client.open("Stock Market Data")
        sheet = spreadsheet.worksheet("Stock Selection")
        print("✅ Successfully connected to Google Sheets!")
        break
    except Exception as e:
        print(f"❌ Failed to connect to Google Sheets (Attempt {attempt + 1}/5): {e}")
        time.sleep(5)  # Wait and retry
else:
    raise Exception("🚨 Could not connect to Google Sheets after multiple attempts.")

# 🔹 Kafka Configuration
KAFKA_SERVER = "192.168.125.254:9092"  # Update with your Kafka server IP
TOPIC = "stock_market_realtime"

producer = KafkaProducer(
    bootstrap_servers=KAFKA_SERVER,
    value_serializer=lambda v: json.dumps(v).encode("utf-8")
)

while True:
    try:
        # 🔹 Read selected stock from Google Sheets (B2)
        selected_stock = sheet.acell("B2").value.strip().upper()  # Remove spaces & convert to uppercase

        # 🔹 Check if stock exists before adding `.NS`
        stock_check = yf.Ticker(selected_stock).info
        if "symbol" not in stock_check:
            print(f"⚠️ Invalid stock symbol '{selected_stock}'. Skipping...")
            time.sleep(60)
            continue

        print(f"📈 Fetching data for {selected_stock}...")

        stock_data = yf.Ticker(selected_stock).history(period="1d", interval="1m")

        if stock_data.empty:
            print(f"⚠️ No stock data found for {selected_stock}. Skipping...")
            time.sleep(60)
            continue  # Skip this iteration

        latest = stock_data.iloc[-1]
        data = {
            "timestamp": str(latest.name),
            "stock": selected_stock,
            "price": latest["Close"],
            "open": latest["Open"],
            "high": latest["High"],
            "low": latest["Low"],
            "previous_close": stock_check.get("previousClose", "N/A"),
            "volume": latest["Volume"]
        }

        # 🔹 Send Data to Kafka
        producer.send(TOPIC, data)
        print(f"📤 Sent data: {data}")

    except Exception as e:
        print(f"❌ Error: {e}")

    time.sleep(20)  # Fetch data every minute
# Out:
# ✅ Successfully connected to Google Sheets!
# 📈 Fetching data for META...
# 📤 Sent data: {'timestamp': '2025-03-20 11:23:00-04:00', 'stock': 'META', 'price': np.float64(607.8499755859375), 'open': np.float64(607.8499755859375), 'high': np.float64(607.8499755859375), 'low': np.float64(607.8499755859375), 'previous_close': 584.06, 'volume': np.float64(0.0)}
# 📈 Fetching data for META...
# 📤 Sent data: {'timestamp': '2025-03-20 11:23:00-04:00', 'stock': 'META', 'price': np.float64(607.8699951171875), 'open': np.float64(607.8699951171875), 'high': np.float64(607.8699951171875), 'low': np.float64(607.8699951171875), 'previous_close': 584.06, 'volume': np.float64(0.0)}
# 📈 Fetching data for TSLA...
# 📤 Sent data: {'timestamp': '2025-03-20 11:23:00-04:00', 'stock': 'TSLA', 'price': np.float64(235.80999755859375), 'open': np.float64(235.80999755859375), 'high': np.float64(235.80999755859375), 'low': np.float64(235.80999755859375), 'previous_close': 235.86, 'volume': np.float64(0.0)}
# 📈 Fetching data for TSLA...
# 📤 Sent data: {'timestamp': '2025-03-20 11:24:00-04:00', 'stock': 'TSLA', 'price': np.float64(235.3126983642578), 'open': np.float64(235.3126983642578), 'high': np.float64(235.3126983642578), 'low': np.float64(235.3126983642578), 'previous_close': 235.86, 'volume': np.float64(0.0)}
# 📈 Fetching data for TSLA...
# 📤 Sent data: {'timestamp': '2025-03-20 11:24:00-04:00', 'stock': 'TSLA', 'price': np.float64(235.25), 'open': np.float64(235.25), 'high': np.float64(235.25), 'low': np.float64(235.25), 'previous_close': 235.86, 'volume': np.float64(0.0)}
# 📈 Fetching data for TSLA...
# 📤 Sent data: {'timestamp': '2025-03-20 11:25:00-04:00', 'stock': 'TSLA', 'price': np.float64(235.2899932861328), 'open': np.float64(235.2899932861328), 'high': np.float64(235.2899932861328), 'low': np.float64(235.2899932861328), 'previous_close': 235.86, 'volume': np.float64(0.0)}
# 📈 Fetching data for AAPL...
# 📤 Sent data: {'timestamp': '2025-03-20 11:25:00-04:00', 'stock': 'AAPL', 'price': np.float64(216.02000427246094), 'open': np.float64(216.02000427246094), 'high': np.float64(216.02000427246094), 'low': np.float64(216.02000427246094), 'previous_close': 215.24, 'volume': np.float64(0.0)}
# 📈 Fetching data for AAPL...
# 📤 Sent data: {'timestamp': '2025-03-20 11:25:00-04:00', 'stock': 'AAPL', 'price': np.float64(216.0050048828125), 'open': np.float64(216.0050048828125), 'high': np.float64(216.0050048828125), 'low': np.float64(216.0050048828125), 'previous_close': 215.24, 'volume': np.float64(0.0)}
# 📈 Fetching data for AAPL...
# 📤 Sent data: {'timestamp': '2025-03-20 11:26:00-04:00', 'stock': 'AAPL', 'price': np.float64(216.00999450683594), 'open': np.float64(216.00999450683594), 'high': np.float64(216.00999450683594), 'low': np.float64(216.00999450683594), 'previous_close': 215.24, 'volume': np.float64(0.0)}
# 📈 Fetching data for AAPL...
# 📤 Sent data: {'timestamp': '2025-03-20 11:26:00-04:00', 'stock': 'AAPL', 'price': np.float64(216.0399932861328), 'open': np.float64(216.0399932861328), 'high': np.float64(216.0399932861328), 'low': np.float64(216.0399932861328), 'previous_close': 215.24, 'volume': np.float64(0.0)}
# 📈 Fetching data for AAPL...
# 📤 Sent data: {'timestamp': '2025-03-20 11:26:00-04:00', 'stock': 'AAPL', 'price': np.float64(216.0500030517578), 'open': np.float64(216.0500030517578), 'high': np.float64(216.0500030517578), 'low': np.float64(216.0500030517578), 'previous_close': 215.24, 'volume': np.float64(0.0)}
# 📈 Fetching data for AAPL...
# 📤 Sent data: {'timestamp': '2025-03-20 11:27:00-04:00', 'stock': 'AAPL', 'price': np.float64(216.0399932861328), 'open': np.float64(216.0399932861328), 'high': np.float64(216.0399932861328), 'low': np.float64(216.0399932861328), 'previous_close': 215.24, 'volume': np.float64(0.0)}
# 📈 Fetching data for IBM...
# 📤 Sent data: {'timestamp': '2025-03-20 11:27:00-04:00', 'stock': 'IBM', 'price': np.float64(244.4600067138672), 'open': np.float64(244.4600067138672), 'high': np.float64(244.4600067138672), 'low': np.float64(244.4600067138672), 'previous_close': 252.29, 'volume': np.float64(0.0)}
# 📈 Fetching data for IBM...
# 📤 Sent data: {'timestamp': '2025-03-20 11:27:00-04:00', 'stock': 'IBM', 'price': np.float64(244.4600067138672), 'open': np.float64(244.4600067138672), 'high': np.float64(244.4600067138672), 'low': np.float64(244.4600067138672), 'previous_close': 252.29, 'volume': np.float64(0.0)}
# 📈 Fetching data for IBM...
# 📤 Sent data: {'timestamp': '2025-03-20 11:28:00-04:00', 'stock': 'IBM', 'price': np.float64(244.52000427246094), 'open': np.float64(244.52000427246094), 'high': np.float64(244.52000427246094), 'low': np.float64(244.52000427246094), 'previous_close': 252.29, 'volume': np.float64(0.0)}
# 📈 Fetching data for IBM...
# 📤 Sent data: {'timestamp': '2025-03-20 11:28:00-04:00', 'stock': 'IBM', 'price': np.float64(244.40499877929688), 'open': np.float64(244.40499877929688), 'high': np.float64(244.40499877929688), 'low': np.float64(244.40499877929688), 'previous_close': 252.29, 'volume': np.float64(0.0)}
# 📈 Fetching data for IBM...
# 📤 Sent data: {'timestamp': '2025-03-20 11:28:00-04:00', 'stock': 'IBM', 'price': np.float64(244.33999633789062), 'open': np.float64(244.33999633789062), 'high': np.float64(244.33999633789062), 'low': np.float64(244.33999633789062), 'previous_close': 252.29, 'volume': np.float64(0.0)}
# 📈 Fetching data for IBM...
# 📤 Sent data: {'timestamp': '2025-03-20 11:29:00-04:00', 'stock': 'IBM', 'price': np.float64(244.4575958251953), 'open': np.float64(244.4575958251953), 'high': np.float64(244.4575958251953), 'low': np.float64(244.4575958251953), 'previous_close': 252.29, 'volume': np.float64(0.0)}
# 📈 Fetching data for GOOG...
# 📤 Sent data: {'timestamp': '2025-03-20 11:29:00-04:00', 'stock': 'GOOG', 'price': np.float64(166.322998046875), 'open': np.float64(166.322998046875), 'high': np.float64(166.322998046875), 'low': np.float64(166.322998046875), 'previous_close': 166.28, 'volume': np.float64(0.0)}
# 📈 Fetching data for GOOG...
# 📤 Sent data: {'timestamp': '2025-03-20 11:30:00-04:00', 'stock': 'GOOG', 'price': np.float64(166.3300018310547), 'open': np.float64(166.3300018310547), 'high': np.float64(166.3300018310547), 'low': np.float64(166.3300018310547), 'previous_close': 166.28, 'volume': np.float64(0.0)}
# 📈 Fetching data for GOOG...
# 📤 Sent data: {'timestamp': '2025-03-20 11:30:00-04:00', 'stock': 'GOOG', 'price': np.float64(166.3350067138672), 'open': np.float64(166.3350067138672), 'high': np.float64(166.3350067138672), 'low': np.float64(166.3350067138672), 'previous_close': 166.28, 'volume': np.float64(0.0)}
# 📈 Fetching data for GOOG...
# 📤 Sent data: {'timestamp': '2025-03-20 11:30:00-04:00', 'stock': 'GOOG', 'price': np.float64(166.27000427246094), 'open': np.float64(166.27000427246094), 'high': np.float64(166.27000427246094), 'low': np.float64(166.27000427246094), 'previous_close': 166.28, 'volume': np.float64(0.0)}
# 📈 Fetching data for GOOG...
# 📤 Sent data: {'timestamp': '2025-03-20 11:31:00-04:00', 'stock': 'GOOG', 'price': np.float64(166.14999389648438), 'open': np.float64(166.14999389648438), 'high': np.float64(166.14999389648438), 'low': np.float64(166.14999389648438), 'previous_close': 166.28, 'volume': np.float64(0.0)}
# 📈 Fetching data for GOOG...
# 📤 Sent data: {'timestamp': '2025-03-20 11:31:00-04:00', 'stock': 'GOOG', 'price': np.float64(166.07940673828125), 'open': np.float64(166.07940673828125), 'high': np.float64(166.07940673828125), 'low': np.float64(166.07940673828125), 'previous_close': 166.28, 'volume': np.float64(0.0)}
# 📈 Fetching data for GOOG...
# 📤 Sent data: {'timestamp': '2025-03-20 11:31:00-04:00', 'stock': 'GOOG', 'price': np.float64(166.05999755859375), 'open': np.float64(166.05999755859375), 'high': np.float64(166.05999755859375), 'low': np.float64(166.05999755859375), 'previous_close': 166.28, 'volume': np.float64(0.0)}
# 📈 Fetching data for GOOG...
# 📤 Sent data: {'timestamp': '2025-03-20 11:32:00-04:00', 'stock': 'GOOG', 'price': np.float64(166.07029724121094), 'open': np.float64(166.07029724121094), 'high': np.float64(166.07029724121094), 'low': np.float64(166.07029724121094), 'previous_close': 166.28, 'volume': np.float64(0.0)}
# 📈 Fetching data for GOOG...
# 📤 Sent data: {'timestamp': '2025-03-20 11:32:00-04:00', 'stock': 'GOOG', 'price': np.float64(166.13999938964844), 'open': np.float64(166.13999938964844), 'high': np.float64(166.13999938964844), 'low': np.float64(166.13999938964844), 'previous_close': 166.28, 'volume': np.float64(0.0)}
# 📈 Fetching data for GOOG...
# 📤 Sent data: {'timestamp': '2025-03-20 11:32:00-04:00', 'stock': 'GOOG', 'price': np.float64(166.07000732421875), 'open': np.float64(166.07000732421875), 'high': np.float64(166.07000732421875), 'low': np.float64(166.07000732421875), 'previous_close': 166.28, 'volume': np.float64(0.0)}
# 📈 Fetching data for GOOG...
# 📤 Sent data: {'timestamp': '2025-03-20 11:33:00-04:00', 'stock': 'GOOG', 'price': np.float64(166.0948944091797), 'open': np.float64(166.0948944091797), 'high': np.float64(166.0948944091797), 'low': np.float64(166.0948944091797), 'previous_close': 166.28, 'volume': np.float64(0.0)}
# 📈 Fetching data for GOOG...
# 📤 Sent data: {'timestamp': '2025-03-20 11:33:00-04:00', 'stock': 'GOOG', 'price': np.float64(165.97999572753906), 'open': np.float64(165.97999572753906), 'high': np.float64(165.97999572753906), 'low': np.float64(165.97999572753906), 'previous_close': 166.28, 'volume': np.float64(0.0)}
# 📈 Fetching data for GOOG...
# 📤 Sent data: {'timestamp': '2025-03-20 11:34:00-04:00', 'stock': 'GOOG', 'price': np.float64(165.97000122070312), 'open': np.float64(165.97000122070312), 'high': np.float64(165.97000122070312), 'low': np.float64(165.97000122070312), 'previous_close': 166.28, 'volume': np.float64(0.0)}
# 📈 Fetching data for GOOG...
# 📤 Sent data: {'timestamp': '2025-03-20 11:34:00-04:00', 'stock': 'GOOG', 'price': np.float64(165.78500366210938), 'open': np.float64(165.78500366210938), 'high': np.float64(165.78500366210938), 'low': np.float64(165.78500366210938), 'previous_close': 166.28, 'volume': np.float64(0.0)}
# 📈 Fetching data for GOOG...
# 📤 Sent data: {'timestamp': '2025-03-20 11:34:00-04:00', 'stock': 'GOOG', 'price': np.float64(165.7899932861328), 'open': np.float64(165.7899932861328), 'high': np.float64(165.7899932861328), 'low': np.float64(165.7899932861328), 'previous_close': 166.28, 'volume': np.float64(0.0)}
# 📈 Fetching data for GOOG...
# 📤 Sent data: {'timestamp': '2025-03-20 11:35:00-04:00', 'stock': 'GOOG', 'price': np.float64(165.77999877929688), 'open': np.float64(165.77999877929688), 'high': np.float64(165.77999877929688), 'low': np.float64(165.77999877929688), 'previous_close': 166.28, 'volume': np.float64(0.0)}
# 📈 Fetching data for GOOG...
# 📤 Sent data: {'timestamp': '2025-03-20 11:35:00-04:00', 'stock': 'GOOG', 'price': np.float64(165.77000427246094), 'open': np.float64(165.77000427246094), 'high': np.float64(165.77000427246094), 'low': np.float64(165.77000427246094), 'previous_close': 166.28, 'volume': np.float64(0.0)}
# 📈 Fetching data for GOOG...
# 📤 Sent data: {'timestamp': '2025-03-20 11:35:00-04:00', 'stock': 'GOOG', 'price': np.float64(165.72230529785156), 'open': np.float64(165.72230529785156), 'high': np.float64(165.72230529785156), 'low': np.float64(165.72230529785156), 'previous_close': 166.28, 'volume': np.float64(0.0)}
# 📈 Fetching data for GOOG...
# 📤 Sent data: {'timestamp': '2025-03-20 11:36:00-04:00', 'stock': 'GOOG', 'price': np.float64(165.72999572753906), 'open': np.float64(165.72999572753906), 'high': np.float64(165.72999572753906), 'low': np.float64(165.72999572753906), 'previous_close': 166.28, 'volume': np.float64(0.0)}
# 📈 Fetching data for AAPL...
# 📤 Sent data: {'timestamp': '2025-03-20 11:36:00-04:00', 'stock': 'AAPL', 'price': np.float64(215.6999969482422), 'open': np.float64(215.6999969482422), 'high': np.float64(215.6999969482422), 'low': np.float64(215.6999969482422), 'previous_close': 215.24, 'volume': np.float64(0.0)}
# 📈 Fetching data for AAPL...
# 📤 Sent data: {'timestamp': '2025-03-20 11:37:00-04:00', 'stock': 'AAPL', 'price': np.float64(215.52000427246094), 'open': np.float64(215.52000427246094), 'high': np.float64(215.52000427246094), 'low': np.float64(215.52000427246094), 'previous_close': 215.24, 'volume': np.float64(0.0)}
# 📈 Fetching data for AAPL...
# 📤 Sent data: {'timestamp': '2025-03-20 11:37:00-04:00', 'stock': 'AAPL', 'price': np.float64(215.69000244140625), 'open': np.float64(215.69000244140625), 'high': np.float64(215.69000244140625), 'low': np.float64(215.69000244140625), 'previous_close': 215.24, 'volume': np.float64(0.0)}
# 📈 Fetching data for AAPL...
# 📤 Sent data: {'timestamp': '2025-03-20 11:37:00-04:00', 'stock': 'AAPL', 'price': np.float64(215.77999877929688), 'open': np.float64(215.77999877929688), 'high': np.float64(215.77999877929688), 'low': np.float64(215.77999877929688), 'previous_close': 215.24, 'volume': np.float64(0.0)}
# 📈 Fetching data for AAPL...
# 📤 Sent data: {'timestamp': '2025-03-20 11:38:00-04:00', 'stock': 'AAPL', 'price': np.float64(215.82000732421875), 'open': np.float64(215.82000732421875), 'high': np.float64(215.82000732421875), 'low': np.float64(215.82000732421875), 'previous_close': 215.24, 'volume': np.float64(0.0)}
# 📈 Fetching data for AAPL...
# 📤 Sent data: {'timestamp': '2025-03-20 11:38:00-04:00', 'stock': 'AAPL', 'price': np.float64(215.81199645996094), 'open': np.float64(215.81199645996094), 'high': np.float64(215.81199645996094), 'low': np.float64(215.81199645996094), 'previous_close': 215.24, 'volume': np.float64(0.0)}
# 📈 Fetching data for AAPL...
# 📤 Sent data: {'timestamp': '2025-03-20 11:38:00-04:00', 'stock': 'AAPL', 'price': np.float64(215.72000122070312), 'open': np.float64(215.72000122070312), 'high': np.float64(215.72000122070312), 'low': np.float64(215.72000122070312), 'previous_close': 215.24, 'volume': np.float64(0.0)}
# 📈 Fetching data for AAPL...
# 📤 Sent data: {'timestamp': '2025-03-20 11:39:00-04:00', 'stock': 'AAPL', 'price': np.float64(215.7899932861328), 'open': np.float64(215.7899932861328), 'high': np.float64(215.7899932861328), 'low': np.float64(215.7899932861328), 'previous_close': 215.24, 'volume': np.float64(0.0)}
# 📈 Fetching data for AAPL...
# 📤 Sent data: {'timestamp': '2025-03-20 11:39:00-04:00', 'stock': 'AAPL', 'price': np.float64(215.79010009765625), 'open': np.float64(215.79010009765625), 'high': np.float64(215.79010009765625), 'low': np.float64(215.79010009765625), 'previous_close': 215.24, 'volume': np.float64(0.0)}
# 📈 Fetching data for AAPL...
# 📤 Sent data: {'timestamp': '2025-03-20 11:39:00-04:00', 'stock': 'AAPL', 'price': np.float64(215.9600067138672), 'open': np.float64(215.9600067138672), 'high': np.float64(215.9600067138672), 'low': np.float64(215.9600067138672), 'previous_close': 215.24, 'volume': np.float64(0.0)}
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/HDFC?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=HDFC&crumb=G8Rj8r.iIxv
# ❌ Error: 'NoneType' object has no attribute 'update'
# 📈 Fetching data for NVDA...
# 📤 Sent data: {'timestamp': '2025-03-20 11:40:00-04:00', 'stock': 'NVDA', 'price': np.float64(119.4000015258789), 'open': np.float64(119.4000015258789), 'high': np.float64(119.4000015258789), 'low': np.float64(119.4000015258789), 'previous_close': 117.52, 'volume': np.float64(0.0)}
# 📈 Fetching data for NVDA...
# 📤 Sent data: {'timestamp': '2025-03-20 11:41:00-04:00', 'stock': 'NVDA', 'price': np.float64(119.42500305175781), 'open': np.float64(119.42500305175781), 'high': np.float64(119.42500305175781), 'low': np.float64(119.42500305175781), 'previous_close': 117.52, 'volume': np.float64(0.0)}
# 📈 Fetching data for NVDA...
# 📤 Sent data: {'timestamp': '2025-03-20 11:41:00-04:00', 'stock': 'NVDA', 'price': np.float64(119.36009979248047), 'open': np.float64(119.36009979248047), 'high': np.float64(119.36009979248047), 'low': np.float64(119.36009979248047), 'previous_close': 117.52, 'volume': np.float64(0.0)}
# 📈 Fetching data for NVDA...
# 📤 Sent data: {'timestamp': '2025-03-20 11:41:00-04:00', 'stock': 'NVDA', 'price': np.float64(119.3499984741211), 'open': np.float64(119.3499984741211), 'high': np.float64(119.3499984741211), 'low': np.float64(119.3499984741211), 'previous_close': 117.52, 'volume': np.float64(0.0)}
# 📈 Fetching data for NVDA...
# 📤 Sent data: {'timestamp': '2025-03-20 11:42:00-04:00', 'stock': 'NVDA', 'price': np.float64(119.37860107421875), 'open': np.float64(119.37860107421875), 'high': np.float64(119.37860107421875), 'low': np.float64(119.37860107421875), 'previous_close': 117.52, 'volume': np.float64(0.0)}
# 📈 Fetching data for NVDA...
# 📤 Sent data: {'timestamp': '2025-03-20 11:42:00-04:00', 'stock': 'NVDA', 'price': np.float64(119.56549835205078), 'open': np.float64(119.56549835205078), 'high': np.float64(119.56549835205078), 'low': np.float64(119.56549835205078), 'previous_close': 117.52, 'volume': np.float64(0.0)}
